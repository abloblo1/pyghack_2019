# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data_sets/ticket_sales_by_showing.csv")

# %%
df.head()
# Out:
#          Folder          EventName  InternalEventName  \
# 0  0 - Features  A Fantastic Woman  A Fantastic Woman
# 1  0 - Features  A Fantastic Woman  A Fantastic Woman
# 2  0 - Features  A Fantastic Woman  A Fantastic Woman
# 3  0 - Features  A Fantastic Woman  A Fantastic Woman
# 4  0 - Features  A Fantastic Woman  A Fantastic Woman
#
#                  EventDate      TicketType  Quantity  ItemPrice  Price
# 0  Mar 16, 2018 5:00:00 PM           Adult         6       8.75  52.50
# 1  Mar 16, 2018 5:00:00 PM          Member         1       0.00      0
# 2  Mar 16, 2018 5:00:00 PM  Senior Citizen        13       8.00    104
# 3  Mar 16, 2018 5:00:00 PM         Student         3       8.00     24
# 4  Mar 16, 2018 7:30:00 PM           Adult        22      10.00    220

# %%
print("Quantity and Date:\n", df["Quantity"], df["EventDate"])
# Out:
# Quantity and Date:
#  0         6
# 1         1
# 2        13
# 3         3
# 4        22
# 5         1
# 6         9
# 7         8
# 8         7
# 9         1
# 10        9
# 11       13
# 12        8
# 13        1
# 14       19
# 15        9
# 16        2
# 17       12
# 18        5
# 19        2
# 20       11
# 21        1
# 22        9
# 23        2
# 24        8
# 25        5
# 26        4
# 27        7
# 28        2
# 29        4
#        ...
# 9534      2
# 9535      8
# 9536      1
# 9537    223
# 9538      3
# 9539    244
# 9540      2
# 9541    201
# 9542    246
# 9543    246
# 9544    245
# 9545      1
# 9546    163
# 9547      3
# 9548    244
# 9549      2
# 9550      3
# 9551      2
# 9552    200
# 9553     29
# 9554      1
# 9555    216
# 9556      6
# 9557      1
# 9558    195
# 9559     10
# 9560    236
# 9561     17
# 9562      3
# 9563      1
# Name: Quantity, Length: 9564, dtype: int64 0        Mar 16, 2018 5:00:00 PM
# 1        Mar 16, 2018 5:00:00 PM
# 2        Mar 16, 2018 5:00:00 PM
# 3        Mar 16, 2018 5:00:00 PM
# 4        Mar 16, 2018 7:30:00 PM
# 5        Mar 16, 2018 7:30:00 PM
# 6        Mar 16, 2018 7:30:00 PM
# 7        Mar 16, 2018 7:30:00 PM
# 8        Mar 17, 2018 2:00:00 PM
# 9        Mar 17, 2018 2:00:00 PM
# 10       Mar 17, 2018 2:00:00 PM
# 11       Mar 17, 2018 5:00:00 PM
# 12       Mar 17, 2018 5:00:00 PM
# 13       Mar 17, 2018 5:00:00 PM
# 14       Mar 17, 2018 7:30:00 PM
# 15       Mar 17, 2018 7:30:00 PM
# 16       Mar 17, 2018 7:30:00 PM
# 17       Mar 18, 2018 2:00:00 PM
# 18       Mar 18, 2018 2:00:00 PM
# 19       Mar 18, 2018 2:00:00 PM
# 20       Mar 18, 2018 5:00:00 PM
# 21       Mar 18, 2018 5:00:00 PM
# 22       Mar 18, 2018 5:00:00 PM
# 23       Mar 18, 2018 5:00:00 PM
# 24       Mar 18, 2018 7:30:00 PM
# 25       Mar 18, 2018 7:30:00 PM
# 26       Mar 18, 2018 7:30:00 PM
# 27       Mar 19, 2018 5:00:00 PM
# 28       Mar 19, 2018 5:00:00 PM
# 29       Mar 19, 2018 5:00:00 PM
#                   ...
# 9534    Oct 26, 2018 10:00:00 PM
# 9535    Oct 27, 2018 10:00:00 PM
# 9536    Oct 27, 2018 10:00:00 PM
# 9537    Oct 21, 2016 10:00:00 PM
# 9538    Oct 21, 2016 10:00:00 PM
# 9539    Oct 22, 2016 10:00:00 PM
# 9540    Oct 22, 2016 10:00:00 PM
# 9541    Oct 26, 2016 10:00:00 PM
# 9542    Oct 27, 2016 10:00:00 PM
# 9543    Oct 20, 2017 10:00:00 PM
# 9544    Oct 21, 2017 10:00:00 PM
# 9545    Oct 21, 2017 10:00:00 PM
# 9546    Oct 25, 2017 10:00:00 PM
# 9547    Oct 25, 2017 10:00:00 PM
# 9548    Oct 26, 2017 10:00:00 PM
# 9549    Oct 26, 2017 10:00:00 PM
# 9550     Oct 5, 2018 10:00:00 PM
# 9551     Oct 5, 2018 10:00:00 PM
# 9552     Oct 5, 2018 10:00:00 PM
# 9553     Oct 6, 2018 10:00:00 PM
# 9554     Oct 6, 2018 10:00:00 PM
# 9555     Oct 6, 2018 10:00:00 PM
# 9556    Oct 10, 2018 10:00:00 PM
# 9557    Oct 10, 2018 10:00:00 PM
# 9558    Oct 10, 2018 10:00:00 PM
# 9559    Oct 11, 2018 10:00:00 PM
# 9560    Oct 11, 2018 10:00:00 PM
# 9561      Oct 3, 2018 5:00:00 PM
# 9562      Oct 3, 2018 5:00:00 PM
# 9563      Oct 3, 2018 5:00:00 PM
# Name: EventDate, Length: 9564, dtype: object

# %%
# change the format of the dates to sort by year, then date, then graph a bar graph
# for quantity of tickets sold as Y and month/year as X
df['EventDate'][3]
# Out:
# 'Mar 16, 2018 5:00:00 PM'

# %%
df['EventDate'].size
# Out:
# 9564

# %%
# df[df['A'] > 2]['B'] = new_val  # new_val not set in df

# df.loc[df['A'] > 2, 'B'] = new_val

# df = df[df['A'] > 2]
# df['B'] = new_val


print(df.loc[3, 'EventDate'])
print("hi")
print(df['EventDate'][3][0:6])
print("floop")
df.loc[3, 'EventDate'] = "123"
print(df.loc[3, 'EventDate'])

#df['EventDate'][0]
#df['EventDate'][0] = "ASDAFSDF"
#df['EventDate'][0]
# Out:
# Mar 16, 2018 5:00:00 PM
# hi
# Mar 16
# floop
# 123

# %%
df = pd.read_csv("data_sets/ticket_sales_by_showing.csv")
print("hi")
i = 0
while i < len(df['EventDate']):
    # would do [0:6] for date in month also but if its is march 3rd itll be "mar 3,"
    # df.loc[i, 'EventDate'] = df['EventDate'][i][0:3]
    df.loc[i, 'EventDate'] = df['EventDate'][i][0:3]
    i += 1
    
print("123")
# Out:
# hi
# 123

# %%
print("Date:\n",df['EventDate'])
# Out:
# Date:
#  0       Mar
# 1       Mar
# 2       Mar
# 3       Mar
# 4       Mar
# 5       Mar
# 6       Mar
# 7       Mar
# 8       Mar
# 9       Mar
# 10      Mar
# 11      Mar
# 12      Mar
# 13      Mar
# 14      Mar
# 15      Mar
# 16      Mar
# 17      Mar
# 18      Mar
# 19      Mar
# 20      Mar
# 21      Mar
# 22      Mar
# 23      Mar
# 24      Mar
# 25      Mar
# 26      Mar
# 27      Mar
# 28      Mar
# 29      Mar
#        ...
# 9534    Oct
# 9535    Oct
# 9536    Oct
# 9537    Oct
# 9538    Oct
# 9539    Oct
# 9540    Oct
# 9541    Oct
# 9542    Oct
# 9543    Oct
# 9544    Oct
# 9545    Oct
# 9546    Oct
# 9547    Oct
# 9548    Oct
# 9549    Oct
# 9550    Oct
# 9551    Oct
# 9552    Oct
# 9553    Oct
# 9554    Oct
# 9555    Oct
# 9556    Oct
# 9557    Oct
# 9558    Oct
# 9559    Oct
# 9560    Oct
# 9561    Oct
# 9562    Oct
# 9563    Oct
# Name: EventDate, Length: 9564, dtype: object

# %%
df.head()
# Out:
#          Folder          EventName  InternalEventName EventDate  \
# 0  0 - Features  A Fantastic Woman  A Fantastic Woman       Mar
# 1  0 - Features  A Fantastic Woman  A Fantastic Woman       Mar
# 2  0 - Features  A Fantastic Woman  A Fantastic Woman       Mar
# 3  0 - Features  A Fantastic Woman  A Fantastic Woman       Mar
# 4  0 - Features  A Fantastic Woman  A Fantastic Woman       Mar
#
#        TicketType  Quantity  ItemPrice  Price
# 0           Adult         6       8.75  52.50
# 1          Member         1       0.00      0
# 2  Senior Citizen        13       8.00    104
# 3         Student         3       8.00     24
# 4           Adult        22      10.00    220

# %%
print("1")
plt.bar(df['EventDate'], df['Quantity'], align='center', alpha=0.5)
#plt.xticks(y_pos, objects)
print("2")
plt.ylabel('Quantity Of Tickets')
plt.title('Month Of Year')
print("3")
plt.show()
print("4")
# Out:
# 1
# 2
# 3

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", 
          "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
df['EventDate'] = pd.Categorical(df['EventDate'], categories=months, ordered=True)

df # has 5 columns though I need the column 'date' and 'price'
df.sort_values(by='EventDate',inplace=True) #at this part it is sorted according to date, great
# total=(df.groupby(df['date'].dt.strftime('%B'))['price'].mean()) # Though now it is not as it was but instead the months appear alphabetically

df.head()
# Out:
#             Folder                   EventName           InternalEventName  \
# 2084  0 - Features  If Beale Street Could Talk  If Beale Street Could Talk
# 2985  0 - Features                        Lion                        Lion
# 2984  0 - Features                        Lion                        Lion
# 2983  0 - Features                        Lion                        Lion
# 2982  0 - Features                        Lion                        Lion
#
#      EventDate      TicketType  Quantity  ItemPrice   Price
# 2084       Jan           Adult        17       8.75  148.75
# 2985       Jan  Senior Citizen        27       7.50  202.50
# 2984       Jan           Adult        17       8.25  140.25
# 2983       Jan  Senior Citizen         8       7.50      60
# 2982       Jan            Comp         1       0.00       0

# %%
df['EventDate'], df['Quantity']
# Out:
# (2084    Jan
#  2985    Jan
#  2984    Jan
#  2983    Jan
#  2982    Jan
#  2981    Jan
#  2980    Jan
#  2979    Jan
#  2978    Jan
#  2977    Jan
#  2976    Jan
#  2975    Jan
#  2974    Jan
#  2986    Jan
#  2973    Jan
#  2971    Jan
#  2970    Jan
#  2969    Jan
#  2968    Jan
#  2967    Jan
#  2966    Jan
#  2965    Jan
#  2964    Jan
#  2963    Jan
#  2962    Jan
#  2961    Jan
#  1995    Jan
#  2972    Jan
#  2987    Jan
#  2988    Jan
#         ...
#  458     Dec
#  457     Dec
#  3530    Dec
#  3529    Dec
#  3528    Dec
#  3527    Dec
#  3509    Dec
#  3510    Dec
#  3511    Dec
#  3512    Dec
#  3513    Dec
#  3514    Dec
#  3515    Dec
#  3516    Dec
#  3517    Dec
#  3518    Dec
#  8069    Dec
#  8973    Dec
#  8975    Dec
#  8976    Dec
#  3519    Dec
#  3520    Dec
#  3521    Dec
#  3522    Dec
#  3523    Dec
#  3524    Dec
#  3525    Dec
#  3526    Dec
#  8974    Dec
#  7701    Dec
#  Name: EventDate, Length: 9564, dtype: category
#  Categories (12, object): [Jan < Feb < Mar < Apr ... Sep < Oct < Nov < Dec],
#  2084    17
#  2985    27
#  2984    17
#  2983     8
#  2982     1
#  2981     5
#  2980     4
#  2979    22
#  2978    36
#  2977     3
#  2976    18
#  2975     2
#  2974     1
#  2986     4
#  2973     2
#  2971     2
#  2970    18
#  2969     1
#  2968    10
#  2967     5
#  2966    18
#  2965     2
#  2964    20
#  2963     1
#  2962    12
#  2961    13
#  1995    14
#  2972    19
#  2987    11
#  2988     4
#          ..
#  458      6
#  457      4
#  3530     3
#  3529     7
#  3528    16
#  3527     1
#  3509     4
#  3510     9
#  3511     2
#  3512     5
#  3513    24
#  3514     1
#  3515    20
#  3516     4
#  3517     5
#  3518     2
#  8069     1
#  8973     5
#  8975     3
#  8976    18
#  3519    10
#  3520     1
#  3521     5
#  3522    10
#  3523     1
#  3524    17
#  3525     1
#  3526    19
#  8974    37
#  7701     2
#  Name: Quantity, Length: 9564, dtype: int64)

# %%
plt.bar(df['EventDate'], df['Quantity'])
#plt.xticks(y_pos, objects)
print("2")
plt.ylabel('Quantity Of Tickets')
plt.title('Month Of Year')
plt.show()
# Out:
# 2

# %%
i = 0
jan = feb = mar = apr = may = jun = jul = aug = sep = oct1 = nov = dec = 0
while i < len(df['EventDate']):
    if df['EventDate'] == "Jan":
        jan += df['Quantity']
    elif df['EventDate'] == "Feb":
        feb += df['Quantity']
    elif df['EventDate'] == "Mar":
        mar += df['Quantity']
    elif df['EventDate'] == "Apr":
        apr += df['Quantity']
    elif df['EventDate'] == "May":
        may += df['Quantity']
    elif df['EventDate'] == "Jun":
        jun += df['Quantity']
    elif df['EventDate'] == "Jul":
        jul += df['Quantity']
    elif df['EventDate'] == "Aug":
        aug += df['Quantity']
    elif df['EventDate'] == "Sep":
        sep += df['Quantity']
    elif df['EventDate'] == "Oct":
        oct1 += df['Quantity']
    elif df['EventDate'] == "Nov":
        nov += df['Quantity']
    elif df['EventDate'] == "Dec":
        dec += df['Quantity']
    i += 1

print("jan: ", jan,"\nfeb: ", feb,"\nmar: ", mar,"\napr: ", apr,"\nmay: ", may,"\njun: ", jun,"\njul: ", jul,"\naug: ", aug,"\nsep: ", sep,"\noct: ", oct1,"\nnov: ", nov, "\ndec: ",dec)
        

    # would do [0:6] for date in month also but if its is march 3rd itll be "mar 3,"
    # df.loc[i, 'EventDate'] = df['EventDate'][i][0:3]\
